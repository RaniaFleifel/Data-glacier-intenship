# %% [markdown]
# # Week 6, Data ingestion  & pipeline
#
# ## Task:
#
# * Take any csv/text file of 2+ GB of your choice. --- (You can do this assignment on Google colab)
#
# * Read the file ( Present approach of reading the file )
#
# * Try different methods of file reading eg: Dask, Modin, Ray, pandas and present your findings in term of computational     efficiency
#
# * Perform basic validation on data columns : eg: remove special character , white spaces from the col name
#
# * As you already know the schema hence create a YAML file and write the column name in YAML file. --define separator of
#   read and write file, column name in YAML
#
# * Validate number of columns and column name of ingested file with YAML.
#
# * Write the file in pipe separated text file (|) in gz format.
#
# * Create a summary of the file:
#
#     Total number of rows,
#
#     total number of columns
#
#     file size

# %% [markdown]
# ## Ingesting big .csv file:
# 1) Dask

# %%
# https://www.geeksforgeeks.org/working-with-large-csv-files-in-python/
#https://www.kaggle.com/code/robikscube/flight-cancellation-dataset-eda

import ray
ray.shutdown()

import numpy as np
import time
import os
from dask import dataframe as df1
  
    
read_path = 'D:/datanew/Combined_Flights_2022.csv'
file_stats = os.stat(read_path)
print("File size being read in GB is {:.2f}".format(file_stats.st_size / (1024 * 1024 * 1024)))

# time taken to read data
s_time_dask = time.time()
dask_df = df1.read_csv(read_path)
e_time_dask = time.time()
  
print("Read with dask: ", round(e_time_dask-s_time_dask,3), "seconds")  
display(dask_df.head(2))
# Out:
# File size being read in GB is 1.32
# Read with dask:  0.037 seconds
#    FlightDate                                    Airline Origin Dest  \
# 0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# 0      False     False        1133   1123.0              0.0     -10.0  ...
# 1      False     False         732    728.0              0.0      -4.0  ...
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# 0     1140.0    1220.0     8.0        1245     -17.0       0.0
# 1      744.0     839.0     9.0         849      -1.0       0.0
#
#    ArrivalDelayGroups  ArrTimeBlk  DistanceGroup  DivAirportLandings
# 0                -2.0   1200-1259              1                   0
# 1                -1.0   0800-0859              2                   0
#
# [2 rows x 61 columns]

# %% [markdown]
# 2) Pandas

# %%
import pandas as pd

s_time_pandas = time.time()
pandas_df = pd.read_csv(read_path)
e_time_pandas = time.time()
print("Read with pandas: ", round(e_time_pandas-s_time_pandas,3), "seconds")
#display(pandas_df.head(2))
# Out:
# Read with pandas:  692.9118497371674 seconds

# %%
############################## modin ray 
# #https://modin.readthedocs.io/en/stable/getting_started/quickstart.html
import modin.pandas as pdm

ray.init()
s_time_modin = time.time()
modin_df=pdm.read_csv(read_path)
e_time_modin = time.time()
print("Read with modin: ", round(e_time_modin-s_time_modin,3), "seconds")
modin_df.head(10)
#ERROR: MemoryError: Unable to allocate 64.0 KiB for an array with shape (8192,) and data type int64

# https://vaex.io/docs/installing.html
# import vaex
# s_time_vaex = time.time()
# vaex_df = vaex.from_csv(read_path,dtype=dtypetry)
# e_time_vaex = time.time()
# print("Read with vaex: ", (e_time_vaex-s_time_vaex), "seconds")

# # !conda list vaex
# # import vaex as vv
# # #!conda install -c conda-forge vaex
# Out:
# Read with pandas:  740.9041311740875 seconds
#    FlightDate                                    Airline Origin Dest  \
# 0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 5  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DEN  TUL
# 6  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  LCH
# 7  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    TYS  IAH
# 8  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  AEX
# 9  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  MOB
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# 0      False     False        1133   1123.0              0.0     -10.0  ...
# ...

# %% [markdown]
# The column names to add to the YAML file:

# %%
pandas_df.columns.values.tolist()
# Out:
# ['FlightDate',
#  'Airline',
#  'Origin',
#  'Dest',
#  'Cancelled',
#  'Diverted',
#  'CRSDepTime',
#  'DepTime',
#  'DepDelayMinutes',
#  'DepDelay',
#  'ArrTime',
#  'ArrDelayMinutes',
#  'AirTime',
#  'CRSElapsedTime',
#  'ActualElapsedTime',
#  'Distance',
#  'Year',
#  'Quarter',
#  'Month',
#  'DayofMonth',
#  'DayOfWeek',
#  'Marketing_Airline_Network',
#  'Operated_or_Branded_Code_Share_Partners',
#  'DOT_ID_Marketing_Airline',
#  'IATA_Code_Marketing_Airline',
#  'Flight_Number_Marketing_Airline',
#  'Operating_Airline',
#  'DOT_ID_Operating_Airline',
#  'IATA_Code_Operating_Airline',
#  'Tail_Number',
#  'Flight_Number_Operating_Airline',
#  'OriginAirportID',
#  'OriginAirportSeqID',
#  'OriginCityMarketID',
#  'OriginCityName',
#  'OriginState',
#  'OriginStateFips',
#  'OriginStateName',
#  'OriginWac',
#  'DestAirportID',
#  'DestAirportSeqID',
#  'DestCityMarketID',
#  'DestCityName',
#  'DestState',
#  'DestStateFips',
#  'DestStateName',
#  'DestWac',
# ...

# %% [markdown]
# ## Validation:
#
#     - Lower, remove whitespace and replace special characters by _ in the data file read.
#
#     - If the number of columns and their names from the YAML file is the same as that in the data file read, Validation passed.
#
#     - Else, point out the different columns in both files

# %%
# %%writefile testutility.py
import logging
import os
import subprocess
import yaml
import pandas as pd
import datetime 
import gc
import re


################
# File Reading #
################

def read_config_file(filepath):
    with open(filepath, 'r') as stream:
        try:
            return yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            logging.error(exc)


def col_header_val(df,table_config):
    '''
    replace whitespaces in the column
    and standardized column names
    '''
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace('[^\w]','_',regex=True)
    df.columns = list(map(lambda x: x.strip('_'), list(df.columns)))
    expected_col = list(map(lambda x: x.lower(),  table_config['columns']))
    expected_col.sort()
    df.columns =list(map(lambda x: x.lower(), list(df.columns)))
    df = df.reindex(sorted(df.columns), axis=1)
    if len(df.columns) == len(expected_col) and list(expected_col)  == list(df.columns):
        print("column name and column length validation passed")
        return 1
    else:
        print("column name and column length validation failed")
        mismatched_columns_file = list(set(df.columns).difference(expected_col))
        print("Following File columns are not in the YAML file",mismatched_columns_file)
        missing_YAML_file = list(set(expected_col).difference(df.columns))
        print("Following YAML columns are not in the file uploaded",missing_YAML_file)
        logging.info(f'df columns: {df.columns}')
        logging.info(f'expected columns: {expected_col}')
        return 0
# Out:
# Writing testutility.py

# %% [markdown]
# Prepare the YAML file that parmetrize the process of data ingestion

# %%
# %%writefile ingested_file_info.yaml
# file_type: csv
# dataset_name: Combined_Flights_2022
# file_name: Combined_Flights_2022
# table_name: Combined_Flights_2022
# inbound_delimiter: ","
# outbound_delimiter: "|"
# skip_leading_rows: 1
# columns:
#     - FlightDate
#     - Airline
#     - Origin
#     - Dest
#     - Cancelled
#     - Diverted
#     - CRSDepTime
#     - DepTime
#     - DepDelayMinutes
#     - DepDelay
#     - ArrTime
#     - ArrDelayMinutes
#     - AirTime
#     - CRSElapsedTime
#     - ActualElapsedTime
#     - Distance
#     - Year
#     - Quarter
#     - Month
#     - DayofMonth
#     - DayOfWeek
#     - Marketing_Airline_Network
#     - Operated_or_Branded_Code_Share_Partners
#     - DOT_ID_Marketing_Airline
#     - IATA_Code_Marketing_Airline
#     - Flight_Number_Marketing_Airline
#     - Operating_Airline
#     - DOT_ID_Operating_Airline
#     - IATA_Code_Operating_Airline
#     - Tail_Number
#     - Flight_Number_Operating_Airline
#     - OriginAirportID
#     - OriginAirportSeqID
#     - OriginCityMarketID
#     - OriginCityName
#     - OriginState
#     - OriginStateFips
#     - OriginStateName
#     - OriginWac
#     - DestAirportID
#     - DestAirportSeqID
#     - DestCityMarketID
#     - DestCityName
#     - DestState
#     - DestStateFips
#     - DestStateName
#     - DestWac
#     - DepDel15
#     - DepartureDelayGroups
#     - DepTimeBlk
#     - TaxiOut
#     - WheelsOff
#     - WheelsOn
#     - TaxiIn
#     - CRSArrTime
#     - ArrDelay
#     - ArrDel15
#     - ArrivalDelayGroups
#     - ArrTimeBlk
#     - DistanceGroup
#     - DivAirportLandings
# Out:
# Writing ingested_file_info.yaml

# %%
# Read config file
import testutility as util
config_data = util.read_config_file("ingested_file_info.yaml")
config_data
# Out:
# {'file_type': 'csv',
#  'dataset_name': 'Combined_Flights_2022',
#  'file_name': 'Combined_Flights_2022',
#  'table_name': 'Combined_Flights_2022',
#  'inbound_delimiter': ',',
#  'outbound_delimiter': '|',
#  'skip_leading_rows': 1,
#  'columns': ['FlightDate',
#   'Airline',
#   'Origin',
#   'Dest',
#   'Cancelled',
#   'Diverted',
#   'CRSDepTime',
#   'DepTime',
#   'DepDelayMinutes',
#   'DepDelay',
#   'ArrTime',
#   'ArrDelayMinutes',
#   'AirTime',
#   'CRSElapsedTime',
#   'ActualElapsedTime',
#   'Distance',
#   'Year',
#   'Quarter',
#   'Month',
#   'DayofMonth',
#   'DayOfWeek',
#   'Marketing_Airline_Network',
#   'Operated_or_Branded_Code_Share_Partners',
#   'DOT_ID_Marketing_Airline',
#   'IATA_Code_Marketing_Airline',
#   'Flight_Number_Marketing_Airline',
#   'Operating_Airline',
#   'DOT_ID_Operating_Airline',
#   'IATA_Code_Operating_Airline',
#   'Tail_Number',
#   'Flight_Number_Operating_Airline',
#   'OriginAirportID',
#   'OriginAirportSeqID',
# ...

# %%
# read the file using config file

file_type = config_data['file_type']
source_file ="D:/datanew/" + config_data['file_name'] + f'.{file_type}'
print("",source_file)


df = pd.read_csv(source_file,config_data['inbound_delimiter'])
df.head()
# Out:
#  D:/datanew/Combined_Flights_2022.csv
# C:\Users\Rania Fleifel\AppData\Local\Temp\ipykernel_6192\1925505116.py:8: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df = pd.read_csv(source_file,config_data['inbound_delimiter'])
#    FlightDate                                    Airline Origin Dest  \
# 0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# 0      False     False        1133   1123.0              0.0     -10.0  ...
# 1      False     False         732    728.0              0.0      -4.0  ...
# ...

# %%
#validate the header of the file
util.col_header_val(df,config_data)
# Out:
# column name and column length validation passed
# 1

# %%
print("columns of files are:" ,df.columns.tolist())
print("columns of YAML are:" ,config_data['columns'])
# Out:
# columns of files are: ['flightdate', 'airline', 'origin', 'dest', 'cancelled', 'diverted', 'crsdeptime', 'deptime', 'depdelayminutes', 'depdelay', 'arrtime', 'arrdelayminutes', 'airtime', 'crselapsedtime', 'actualelapsedtime', 'distance', 'year', 'quarter', 'month', 'dayofmonth', 'dayofweek', 'marketing_airline_network', 'operated_or_branded_code_share_partners', 'dot_id_marketing_airline', 'iata_code_marketing_airline', 'flight_number_marketing_airline', 'operating_airline', 'dot_id_operating_airline', 'iata_code_operating_airline', 'tail_number', 'flight_number_operating_airline', 'originairportid', 'originairportseqid', 'origincitymarketid', 'origincityname', 'originstate', 'originstatefips', 'originstatename', 'originwac', 'destairportid', 'destairportseqid', 'destcitymarketid', 'destcityname', 'deststate', 'deststatefips', 'deststatename', 'destwac', 'depdel15', 'departuredelaygroups', 'deptimeblk', 'taxiout', 'wheelsoff', 'wheelson', 'taxiin', 'crsarrtime', 'arrdelay', 'arrdel1
# ...

# %%
if util.col_header_val(df,config_data)==0:
    print("validation failed")
    # write code to reject the file
else:
    print("col validation passed")
    # write the code to perform further action
    # in the pipleine
# Out:
# column name and column length validation passed
# col validation passed

# %% [markdown]
# ## Writing the data file to pipe delimited txt file that is zipped (.gz)

# %%
#https://datascience.stackexchange.com/questions/85590/how-do-i-transform-a-file-to-txt-file-using-pandas
df.to_csv('data.txt.gz', sep='|',index=False,compression='gzip')

# %% [markdown]
# ## Preparing a summary of the data file

# %%
print("The size of the .gz file = {:.2f} MB \nThe size of original csv file = {:.2f} GB ".format(os.stat('data.txt.gz').st_size/(1024*1024),os.stat(source_file).st_size/(1024*1024*1024)))
print("The number of columns = {} \nThe number of rows = {}".format(len(df.columns.tolist()),len(df)))
#df.size=columns*rows
# Out:
# The size of the .gz file = 188.52 MB
# The size of original csv file = 1.32 GB
# The number of columns = 61
# The number of rows = 4078318
